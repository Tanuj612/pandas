# %%
#pandas.series(data,index,dtype,copy)😎
#series have 1d data❤️
import pandas as pd
import numpy as np
np_data=np.arange(4)
s=pd.Series(np_data)
print(s)
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# dtype: int64

# %%
#In dictionary key taken as indexes🤗
import pandas as pd
import numpy as np
data={'a':0.,'b':1.,'c':2.}
s=pd.Series(data)
print(s)
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
import pandas as pd
import numpy as np
data={'a':0.,'b':1.,'c':2.}
s=pd.Series(data,index=['b','c','d','a'])
print(s)
# Out:
# b    1.0
# c    2.0
# d    NaN
# a    0.0
# dtype: float64

# %%
import pandas as pd
import numpy as np
s=pd.Series(5,index=[0,1,2,3])
print(s)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %%
import pandas as pd
import numpy as np
s=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])

print(s[0])
print(s[:3])
# Out:
# 1
# a    1
# b    2
# c    3
# dtype: int64

# %%
#data has two index one have array and second have pandas means '1' has 0 and a both indexing👌
import pandas as pd
import numpy as np
s=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])

print(s['a'])
print(s[0])
print(s[['a','b','c']])
# Out:
# 1
# 1
# a    1
# b    2
# c    3
# dtype: int64

# %%
#pandas.Dataframe(data,index,column)😍
#used for 2d data👍
import pandas as pd
data=[1,2,3,4,5]
df=pd.DataFrame(data)
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
import pandas as pd
data=[['Alex',11],['Bob',12]]
df=pd.DataFrame(data,columns=['Name','Age'])
print(df)
# Out:
#    Name  Age
# 0  Alex   11
# 1   Bob   12

# %%
import numpy as np
import pandas as pd
a=np.array(['a','b','c','d'])
b=pd.Series(a)
print(b)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
# maza aagya🤗
import numpy as np
import pandas as pd
a=np.array([['a','b','c'],[1,2,3]])
a.shape=(3,2)
b=pd.DataFrame(a,columns=['t','y'])
print(b)
# Out:
#    t  y
# 0  a  b
# 1  c  1
# 2  2  3

# %%
import pandas as pd
data=[{'a':1,'b':2},{'a':5,'b':10}]
df=pd.DataFrame(data)
print(df)
# Out:
#    a   b
# 0  1   2
# 1  5  10

# %%
# In dictionary if we have 1d then key taken as index but in 2d key is taken as column😯
import pandas as pd
data=[{'a':1,'b':2},{'a':5,'b':10}]
df=pd.DataFrame(data,index=['first','second'])
print(df)
# Out:
#         a   b
# first   1   2
# second  5  10

# %%
# column selection😊
import pandas as pd
d={'one':pd.Series([1,2,3,],index=['a','b','c']),'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df=pd.DataFrame(d)
print(df)
print(df['one'])
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64

# %%
# column addition and sum of the given columns 👍
import pandas as pd
d={'one':pd.Series([1,2,3,],index=['a','b','c']),'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df=pd.DataFrame(d)
df['three']=pd.Series([10,20,30],index=['a','b','c'])
df['four']=df['one']+df['three']
print(df)
# Out:
#    one  two  three  four
# a  1.0    1   10.0  11.0
# b  2.0    2   20.0  22.0
# c  3.0    3   30.0  33.0
# d  NaN    4    NaN   NaN

# %%
# for delete the column using del function and pop method😁
import pandas as pd
d={'one':pd.Series([1,2,3,],index=['a','b','c']),'two':pd.Series([1,2,3,4],index=['a','b','c','d']),'three':pd.Series([10,20,30],index=['a','b','c'])}
df=pd.DataFrame(d)
print(df)
del df['one']
print(df)
df.pop('two')
print(df)
# Out:
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN
#    two  three
# a    1   10.0
# b    2   20.0
# c    3   30.0
# d    4    NaN
#    three
# a   10.0
# b   20.0
# c   30.0
# d    NaN

# %%
import pandas as pd
import numpy as np
s=pd.Series(np.random.randn(4))
print(s.axes)
# Out:
# [RangeIndex(start=0, stop=4, step=1)]

# %%
# check whether it is empty or not🍿
import pandas as pd
import numpy as np
s=pd.Series(np.random.randn(4))
print(s.empty)
# Out:
# False

# %%
# ndim function✌️
import pandas as pd
import numpy as np
s=pd.DataFrame(np.random.randn(4))
print(s.ndim)
# Out:
# 2

# %%
# size function👍
import pandas as pd
import numpy as np
s=pd.Series(np.random.randn(4))
print(s.size)
# Out:
# 4

# %%
import pandas as pd
import numpy as np
s=pd.Series(np.random.randn(4))
print(s.values)
# Out:
# [-0.1427963   1.24262871  0.76601596  0.2636237 ]

# %%
# head() return the first n value and tail() return the last n value 🥱
import pandas as pd
import numpy as np
s=pd.Series([1,2,3,4])
print(s.head(2))
print(s.tail(2))
# Out:
# 0    1
# 1    2
# dtype: int64
# 2    3
# 3    4
# dtype: int64

# %%
# for transpose 🙃
import pandas as pd
d={'name':pd.Series(['tom','james','ricky']),'age':pd.Series([23,26,27]),'rating':pd.Series([4.23,4.6,3.8])}
df=pd.DataFrame(d)
print(df.T)
# Out:
#            0      1      2
# name     tom  james  ricky
# age       23     26     27
# rating  4.23    4.6    3.8

# %%
# shape gives the order 🥹
import pandas as pd
d={'name':pd.Series(['tom','james','ricky']),'age':pd.Series([23,26,27]),'rating':pd.Series([4.23,4.6,3.8])}
df=pd.DataFrame(d)
print(df.shape)
# Out:
# (3, 3)
